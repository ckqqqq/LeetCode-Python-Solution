# %% [markdown]
# 25. Reverse Nodes in k-Group
# Hard
# 10.1K
# 557
# Companies
# Given the head of a linked list, reverse the nodes of the list k at a time, and return the modified list.
#
# k is a positive integer and is less than or equal to the length of the linked list. If the number of nodes is not a multiple of k then left-out nodes, in the end, should remain as it is.
#
# You may not alter the values in the list's nodes, only nodes themselves may be changed.
#
#
#
# Example 1:
#
#
# Input: head = [1,2,3,4,5], k = 2
# Output: [2,1,4,3,5]
# Example 2:
#
#
# Input: head = [1,2,3,4,5], k = 3
# Output: [3,2,1,4,5]
#
#
# Constraints:
#
# The number of nodes in the list is n.
# 1 <= k <= n <= 5000
# 0 <= Node.val <= 1000
#
#
# Follow-up: Can you solve the problem in O(1) extra memory space?
#
# Accepted
# 644.4K
# Submissions
# 1.2M
# Acceptance Rate
# 54.1%
# Seen this question in a real interview before?
# 1/4

# %% [markdown]
# **反转链表**
# 1-2-3-4-5
# cur
# 2-3-4-5
# newtail
# 1-
# c
# 3-4-5
#   n
# 2-1-
# old_head
# prev
# 4-5
# 3-2-1
# head   tail
# 5-4-3-2-1
#
#
#
# 单纯

# %% [markdown]
# 25. Reverse Nodes in k-Group
# Hard
# 10.1K
# 557
# Companies
# Given the head of a linked list, reverse the nodes of the list k at a time, and return the modified list.
#
# k is a positive integer and is less than or equal to the length of the linked list. If the number of nodes is not a multiple of k then left-out nodes, in the end, should remain as it is.
#
# You may not alter the values in the list's nodes, only nodes themselves may be changed.
#
#
#
# Example 1:
#
#
# Input: head = [1,2,3,4,5], k = 2
# Output: [2,1,4,3,5]
# Example 2:
#
#
# Input: head = [1,2,3,4,5], k = 3
# Output: [3,2,1,4,5]
#
#
# Constraints:
#
# The number of nodes in the list is n.
# 1 <= k <= n <= 5000
# 0 <= Node.val <= 1000
#
#
# Follow-up: Can you solve the problem in O(1) extra memory space?
#
# Accepted
# 644.4K
# Submissions
# 1.2M
# Acceptance Rate
# 54.1%
# Seen this question in a real interview before?
# 1/4

# %%
# 重大胜利! 除虫射日
# 还不错吧 68 80
# 1-2-3-4-5-
class Solution(object):
    def reverseKGroup(self, head, k):
        def reverse(old_head,k):
            '''
            这个函数的意义是从old_head节点开始
            返回new_head(old_tail)
            '''
            if not old_head:
                return None
            counter=1
            cur=old_head
            old_tail=None
            while cur!=None and counter<=k:
                tmp_next_cur=cur.next#暂存下一个
                cur.next=old_tail#指向前面那个节点
                old_tail=cur#更新前面节点
                cur=tmp_next_cur#循环下一个
                counter+=1# 计数，从1开始
            if counter<=k:# 提前退出
                return reverse(old_tail,counter-1)# 4-3-2-1-None 返回 1-2-3-4-None
            else:
                old_head.next=reverse(cur,k)
                #此时的 oldhead==newtail oldtail==newhead
                return old_tail
        # parent def
        if k<=1:
            return head
        result_head=NodeList(10086,None)
        result_head.next=reverse(head,k)
